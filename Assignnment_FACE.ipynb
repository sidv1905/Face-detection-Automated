# %%
from google.colab import drive
drive.mount('/gdrive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive/

# %%
# %cd /gdrive/My\ Drive/Face_Detection
# Out:
# /gdrive/My Drive/Face_Detection

# %%
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import face_recognition

# %%
pip install cmake dlib face_recognition opencv-python
# Out:
# ...
#      |████████████████████████████████| 100.2MB 100kB/s
# ...
#   Created wheel for face-recognition-models: filename=face_recognition_models-0.3.0-py2.py3-none-any.whl size=100566176 sha256=1fbb6126219fc62749e2a4fc25cc6298d07459408992503c4efb3b43ae173594
#   Stored in directory: /root/.cache/pip/wheels/d2/99/18/59c6c8f01e39810415c0e63f5bede7d83dfb0ffc039865465f
# Successfully built face-recognition-models
# ...

# %%
image=cv2.imread("test3.jpg")
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7FB31A9D4DA0>

# %%
img=face_recognition.load_image_file("test3.jpg")

# %%
loc=face_recognition.face_locations(image)
loc
# Out:
# [(14, 165, 50, 129), (46, 81, 82, 45)]

# %%
face1=cv2.rectangle(image,(129,14),(165,50),(255,0,0),2) # TRBL
cv2.putText(image,"Obama",(135,24),cv2.FONT_HERSHEY_SIMPLEX,0.5,(255,255,255),2)
face2=cv2.rectangle(image,(45,46),(81,82),(255,0,0),2)
cv2.putText(image,"Modi",(55,56),cv2.FONT_HERSHEY_SIMPLEX,0.5,(255,255,255),2)
# Out:
# array([[[159, 223, 234],
#         [159, 223, 234],
#         [162, 223, 233],
#         ...,
#         [196, 238, 243],
#         [198, 239, 242],
#         [198, 239, 242]],
#
#        [[159, 223, 234],
#         [159, 223, 234],
#         [162, 223, 233],
#         ...,
#         [196, 238, 243],
#         [198, 239, 242],
#         [198, 239, 242]],
#
#        [[159, 223, 234],
#         [159, 223, 234],
#         [162, 223, 233],
#         ...,
#         [195, 237, 242],
#         [197, 238, 241],
#         [197, 238, 241]],
#
#        ...,
#
#        [[ 29,  88, 150],
#         [ 27,  88, 154],
#         [ 20,  88, 163],
#         ...,
#         [ 49, 101, 154],
#         [ 49, 101, 154],
#         [ 49, 101, 154]],
#
#        [[ 33,  96, 154],
#         [ 30,  95, 156],
#         [ 22,  92, 162],
#         ...,
#         [ 47, 100, 157],
#         [ 47, 101, 156],
#         [ 46, 100, 155]],
#
#        [[ 34,  98, 153],
#         [ 30,  96, 155],
#         [ 23,  93, 163],
# ...

# %%
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=259x194 at 0x7FB2DC3CEF28>

# %%
known=face_recognition.load_image_file("test5.jpg")
unknown=face_recognition.load_image_file("test3.jpg")
known_en=face_recognition.face_encodings(known)[1]
unknown_en=face_recognition.face_encodings(unknown)[1]

# %%
result=face_recognition.compare_faces([known_en],unknown_en)

# %%
result
# Out:
# [True]
